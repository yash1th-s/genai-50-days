# %%
# %pip install google-genai python-dotenv
# Out:
# Requirement already satisfied: google-genai in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (1.61.0)
# Requirement already satisfied: python-dotenv in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (1.2.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.48.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (46.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.2)
# Requirement already satisfied: cffi>=2.0.0 in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /Users/I528710/Desktop/Yash/genai-50-days/venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (3.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.environ["API_KEY"]

client = genai.Client(api_key=os.environ["API_KEY"])
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Hi name is yash. I love to code in python. Write a short bio about me.',
)
print(response.text)
# Out:
# Here are a few options for a short bio for you, Yash, depending on the tone you prefer:
#
# **Option 1 (Concise & Enthusiastic):**
#
# > Yash is a dedicated Python enthusiast who loves diving into code to bring ideas to life. With a passion for problem-solving and building, he enjoys exploring the endless possibilities of the Python language.
#
# **Option 2 (Slightly more descriptive):**
#
# > Meet Yash, a Pythonista at heart! He thrives on the challenge and creativity of coding, finding immense joy in crafting elegant solutions and building applications with Python. Always eager to learn and innovate, Yash is passionate about transforming concepts into functional code.
#
# **Option 3 (Professional/Networking Focus):**
#
# > Yash is a passionate Python developer with a strong affinity for coding. He leverages Python's versatility to tackle challenges and create impactful projects, consistently seeking opportunities to expand his skills and contribute through robust and efficient code.
