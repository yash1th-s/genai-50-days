# %%
# %pip install google-genai python-dotenv

# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

# Load .env file from parent directory
load_dotenv(dotenv_path='../.env')

API_KEY = os.environ["GEMINI_API_KEY"]

client = genai.Client(api_key=API_KEY)
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Hi name is yash. I love to code in python. Write a short bio about me.',
)
print(response.text)
# Out:
# Here are a few options for a short bio for you, Yash, depending on the context:
#
# **Option 1 (Concise & Enthusiastic):**
# "Hi, I'm Yash, and I absolutely love to code in Python! I enjoy bringing ideas to life and solving challenges, one line of code at a time."
#
# **Option 2 (Slightly More Professional/Project-Oriented):**
# "Yash is a passionate Python coder who thrives on building innovative solutions and turning concepts into functional applications. He's always eager to explore new possibilities with Python."
#
# **Option 3 (Short & Sweet, Emphasizing Joy):**
# "Yash is a Python enthusiast through and through, finding immense joy in crafting code to solve problems and create exciting projects."
#
# Choose the one that best fits where you'll be using it!
