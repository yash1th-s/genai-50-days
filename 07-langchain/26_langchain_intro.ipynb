# %% [markdown]
# # Day 26: LangChain Agents
#
# We've built agents from scratch — tool calling, agent loops, the whole thing.
# Now let's do it in **five lines** with LangChain.

# %% [markdown]
# ## Install

# %%
# %pip install langchain langchain-google-genai langgraph requests --quiet

# %% [markdown]
# ## Setup

# %%
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path='../.env')
os.environ["GOOGLE_API_KEY"] = os.environ["GEMINI_API_KEY2"]

# %% [markdown]
# ## The Tool: Real Weather API

# %%
import requests
from langchain.tools import tool

@tool
def get_weather(city: str) -> str:
    """Get current weather for a city."""
    response = requests.get(f"https://wttr.in/{city}?format=3")
    return response.text

# Quick test
print(get_weather.invoke("Tokyo"))
# Out:
# tokyo: â  +14Â°C

# %% [markdown]
# ## Create the Agent

# %%
from langchain.agents import create_agent

agent = create_agent(
    "google_genai:gemini-2.5-flash",
    tools=[get_weather]
)

print("\u2705 Agent ready")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ✅ Agent ready

# %% [markdown]
# ## Run It

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "What's the weather in Tokyo?"}]}
)

print(result["messages"][-1].content)
# Out:
# The weather in Tokyo is 14°C and sunny.

# %% [markdown]
# ## Try Another City

# %%
result = agent.invoke(
    {"messages": [{"role": "user", "content": "How about Seattle"}]}
)

print(result["messages"][-1].content)
# Out:
# The weather in Seattle is +7°C and cloudy.

# %% [markdown]
# ## Key Takeaways
#
# 1. `create_agent` builds a full ReAct agent in **one line** — model + tools, done
# 2. The `@tool` decorator turns any Python function into an agent tool
# 3. The agent **decides when to call tools** — we don't hardcode the flow
