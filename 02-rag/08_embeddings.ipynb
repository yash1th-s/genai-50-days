# %% [markdown]
# # Day 8: Understanding Embeddings
#
# So far, we've been sending text to LLMs and getting text back.
#
# But what if we need to **compare** texts? Or find **similar** documents?
#
# That's where **embeddings** come in.

# %% [markdown]
# ## What is an Embedding?
#
# An embedding converts text into a **vector** — a list of numbers.
#
# ```
# "Hello World" → [0.012, -0.034, 0.056, ..., 0.089]  (3072 numbers)
# ```
#
# These numbers capture the **meaning** of the text, not just the words.
#
# Two sentences with similar meaning will have similar vectors.

# %% [markdown]
# ## Setup

# %%
from google import genai
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path='../.env')
API_KEY = os.environ["GEMINI_API_KEY"]
client = genai.Client(api_key=API_KEY)

# %% [markdown]
# ## Generate an Embedding

# %%
text = "Hello World"

response = client.models.embed_content(
    model="gemini-embedding-001",
    contents=text
)

embedding = response.embeddings[0].values

print(f"Input: '{text}'")
print(f"Vector dimensions: {len(embedding)}")
print(f"First 5 values: {embedding}")
# Out:
# Input: 'Hello World'
# Vector dimensions: 3072
# First 5 values: [-0.015046939, 0.007224771, 0.010408387, -0.06416951, -0.003296465, 0.00021087048, -0.013788601, 0.012758294, 0.006955135, 0.0027825162, -0.012763795, -0.021246223, 0.030361578, 0.047764648, 0.10964752, 0.014141391, -0.005493229, -0.012254291, 0.016399883, -0.014347842, 0.0016168603, -0.007848015, 0.017269338, 0.01300918, -0.03266869, 0.003212574, 0.020221904, 0.0020086032, 0.032555528, 0.018311819, 0.020676704, -0.0114897145, -0.026783135, 0.0074604093, -0.0007540683, 0.016881272, 0.00922744, 0.0002653525, -0.01646248, -0.0070080273, -0.0033590917, 0.009421624, -0.009593557, -0.0054687685, -0.021972029, -0.02350194, -0.009719635, -0.012529851, -0.0047947294, 0.01424776, -0.023526996, -0.020196723, -0.007693768, -0.14930812, -0.009975046, 0.009400769, -0.015323871, 0.030536795, -0.01093062, -0.02422644, -0.0029394834, 0.0059339697, -0.013433221, -0.008600716, 0.00022039568, -0.024070311, -0.0041903853, 0.020025954, -0.021114869, 0.0060108732, 0.02340637, -0.0027061668, 0.009401213, -0.020518497, -0.0037496118, 0.001391381, 0.0002643473, -0.01752991, 0.0077225366, 0.03954088, 0.009727709, -0.012336937, -0.018445222, -0.008630146, -0.007961735, 0.006048396, 0.0028111564, -0.009668987, -0.021507243, 0.0014855615, -0.015720993, 0.00729312, -0.0030744805, 0.010246227, 0.0035079583, -0.003507449, 0.015524367, -0.0073998123, -0.008540573, -0.0066391025, 0.0014545481, -0.00462489, -0.007912579, -0.016445518, -0.0035309163, -0.024883896, 0.035862844, -0.012636165, 0.0024342614, -0.0012414027, -0.009226064, 0.0146722, -0.0039681117, 0.0077111474, 0.021428293, -0.18980756, 0.017619291, 0.010149359, 0.025302527, 0.013574378, 0.0021178925, -0.013830499, -0.0012184475, 0.025720222, 0.01120788, -0.0052448856, -0.0072872406, 0.008945232, 0.0092196325, -0.004020634, -0.014642474, 0.0060418206, -0.0010902677, 0.0020062844, 0.026766624, 0.023710571, -0.0060714292, -0.010961008, -0.0127088325, -0.011740252, -0.0150783695, -0.012903931, -0.004953765, -0.009654225, -0.01514339, -0.023732876, -0.0069279615, 0.014748911, -0.007312111, -0.019906348, -0.010573976, 0.0041949763, -0.031128308, -0.016135389, -0.002798507, -0.044084888, -0.003446226, -0.015131546, -0.0063638263, 0.0021891166, 0.003492669, -0.014983007, -0.0013143963, 0.0049731038, 0.009517395, 0.005963376, -0.034574337, 0.0022938226, -0.007002569, 0.020460714, 0.017229948, -0.0035933822, 0.0073309946, 0.004059433, 0.026948487, 0.004802466, 0.005543528, 0.011255957, 0.020188037, -0.010198814, 0.010117943, 0.018104894, 0.0010379762, -0.021425037, -0.0025994855, -0.00737257, -0.04058632, -0.0055682203, -0.0026894282, -0.0039796615, 0.0053956173, 0.028613573, -0.012647992, 0.00868733, -5.6954712e-05, 0.0015177042, -0.029517755, -0.01308305, 0.016985897, -0.002183598, 0.025562244, -0.0048939227, 0.009313729, -0.0069652973, -0.014491337, 0.0028415674, -0.0004346828, -0.026086567, -0.005110178, 0.013724969, -0.0138035435, -0.016638607, 0.027743861, 0.0016665624, 0.0036144154, 0.001499319, 0.010885309, -0.021672126, -0.0068583605, 3.480922e-05, 0.011704913, 0.008643733, -0.004825382, 0.0046235896, -0.018601915, 0.013534367, -0.011418876, -0.0050144573, 0.011352078, 0.004238511, 0.014855077, 0.019257192, -0.025311468, 0.01601659, -0.00727078, 0.004869725, 0.023973309, 0.004376584, 0.020574572, -0.02110533, -0.023182679, -0.011287944, -0.0005342434, 0.028099695, 0.017364591, 0.019798882, -0.019596346, 0.004259795, 0.0023681342, 0.0060660886, -0.0067572063, 0.023905706, -0.00577129, 0.012769235, -0.0038383896, 0.010963916, -0.014085683, -0.0025869021, 0.008997489, 0.0077575594, -0.0034492093, -0.022261824, -0.023773458, 0.0032175253, -0.0038248338, -0.006824516, 0.0073058927, 0.017195752, 0.0056112623, 0.0081756115, 0.0038396697, -0.017145082, 0.00734388, 0.01598972, 0.006440099, 0.016248882, -0.11851293, 0.0060297693, -0.019534467, -0.008291131, 0.0053498885, 0.0014748106, -0.029984385, -0.01422, 0.029751152, 0.02148186, -0.003119736, -0.016007433, 0.007014358, -0.02326915, -0.000650 ...

# %% [markdown]
# ## What Do These Numbers Mean?
#
# Each number represents a **feature** of the text's meaning.
#
# - The model learned these features during training
# - Individual numbers don't have human-readable labels
# - But combined, they form a unique "fingerprint" of meaning
#
# Think of it like GPS coordinates:
# - `(37.7749, -122.4194)` doesn't tell you "San Francisco"
# - But similar coordinates mean nearby locations

# %% [markdown]
# ### Embedding Multiple Texts

# %%
texts = [
    "Hello World",
    "Hi there, how are you?",
    "Machine learning is fascinating",
    "Deep learning uses neural networks"
]

embeddings = []
for text in texts:
    response = client.models.embed_content(
        model="gemini-embedding-001",
        contents=text
    )
    embeddings.append(response.embeddings[0].values)
    print(f"✅ Generated embedding for: '{text}'")

print(f"\n📊 Total embeddings generated: {len(embeddings)}")
print(f"📐 Each embedding has {len(embeddings[0])} dimensions")
# Out:
# ✅ Generated embedding for: 'Hello World'
# ✅ Generated embedding for: 'Hi there, how are you?'
# ✅ Generated embedding for: 'Machine learning is fascinating'
# ✅ Generated embedding for: 'Deep learning uses neural networks'
#
# 📊 Total embeddings generated: 4
# 📐 Each embedding has 3072 dimensions

# %% [markdown]
# ## Comparing Two Texts

# %%
text_a = "The cat sat on the mat"
text_b = "A feline rested on the rug"

# Get embeddings
emb_a = client.models.embed_content(model="gemini-embedding-001", contents=text_a).embeddings[0].values
emb_b = client.models.embed_content(model="gemini-embedding-001", contents=text_b).embeddings[0].values

print(f"Text A: '{text_a}'")
print(f"Text B: '{text_b}'")
print(f"\nBoth have {len(emb_a)} dimensions")

# %% [markdown]
# ## Measuring Similarity with Cosine
#
# **Cosine similarity** measures how similar two vectors are:
#
# - `1.0` = identical meaning
# - `0.0` = unrelated
# - `-1.0` = opposite meaning (rare in practice)

# %%
import numpy as np

def cosine_similarity(vec1, vec2):
    vec1 = np.array(vec1)
    vec2 = np.array(vec2)
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

similarity = cosine_similarity(emb_a, emb_b)
print(f"Similarity: {similarity:.4f}")

# %% [markdown]
# ## Similar vs Different Texts

# %%
sentences = [
    "Machine learning is a subset of AI",
    "ML is part of artificial intelligence",
    "The weather is nice today"
]

# Generate embeddings
embeddings = []
for s in sentences:
    emb = client.models.embed_content(model="gemini-embedding-001", contents=s).embeddings[0].values
    embeddings.append(emb)

# Compare
print("Comparing sentences:\n")
print(f"1: '{sentences[0]}'")
print(f"2: '{sentences[1]}'")
print(f"3: '{sentences[2]}'")

print(f"\n1 vs 2 (similar meaning): {cosine_similarity(embeddings[0], embeddings[1]):.4f}")
print(f"1 vs 3 (different topic):  {cosine_similarity(embeddings[0], embeddings[2]):.4f}")

# %% [markdown]
# ## Key Takeaways
#
# 1. **Embeddings** convert text to vectors (lists of numbers)
# 2. **Similar meanings** produce similar vectors
# 3. **Cosine similarity** measures how close two vectors are
# 4. Gemini embeddings have **3072 dimensions**
#
# ---
#
# **Next:** Day 9 — Using embeddings for semantic search
